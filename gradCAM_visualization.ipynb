# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

categories_enfants = ['Crèche','PS','MS','GS','CE1','CE2','CM1','CM2']
adultes = ['NOV','EXP']

# %%
# pour le modèle suivant :
enfants_groupe = ['CM1', 'CM2']

# on va voir les dessins de la catégorie :
categorie_visualization = 'CM2'

for heatmap in sorted(os.listdir('CAMs/' + enfants_groupe[0] + enfants_groupe[1] + '/' + categorie_visualization)):
    if 'jpg' in heatmap:
        img = mpimg.imread('CAMs/' + enfants_groupe[0] + enfants_groupe[1] + '/' + categorie_visualization + '/' + heatmap)
        plt.title(categorie_visualization + ' : ' + heatmap[:-4])
        plt.imshow(img)
        plt.savefig('CAMs/all_CAMS/' + categorie_visualization + '-' + heatmap[:-4] + '.png', dpi=400)
        plt.show()

# %% [markdown]
# ### Download all gradCAMS

# %%
os.chdir('CAMs')

# %%
#!tar -czf all_CAMs.tar.gz 'all_CAMS'
